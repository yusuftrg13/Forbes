# %%
import pandas as pd

# %%
veri=pd.read_csv('forbes.csv')

# %%
veri.head(10)
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
# 5     6                Larry Page  49.0    111000.0  2022      4
# 6     7               Sergey Brin  48.0    107000.0  2022      4
# 7     8             Larry Ellison  77.0    106000.0  2022      4
# 8     9             Steve Ballmer  66.0     91400.0  2022      4
# 9    10             Mukesh Ambani  64.0     90700.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# ...

# %%
veri.drop('bio',axis=1,inplace=True)
veri.head(10)
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
# 5     6                Larry Page  49.0    111000.0  2022      4
# 6     7               Sergey Brin  48.0    107000.0  2022      4
# 7     8             Larry Ellison  77.0    106000.0  2022      4
# 8     9             Steve Ballmer  66.0     91400.0  2022      4
# 9    10             Mukesh Ambani  64.0     90700.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# ...

# %%
veri.drop('numberOfSiblings',axis=1,inplace=True)

# %%
veri.drop('philanthropyScore',axis=1,inplace=True)

# %%
veri.drop('about',axis=1,inplace=True)

# %%
veri.drop('residenceMsa',axis=1,inplace=True)
veri.head(10)
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
# 5     6                Larry Page  49.0    111000.0  2022      4
# 6     7               Sergey Brin  48.0    107000.0  2022      4
# 7     8             Larry Ellison  77.0    106000.0  2022      4
# 8     9             Steve Ballmer  66.0     91400.0  2022      4
# 9    10             Mukesh Ambani  64.0     90700.0  2022      4
#
#                 category              source        country       state  \
# 0             Automotive       Tesla, SpaceX  United States       Texas
# 1             Technology              Amazon  United States  Washington
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %%
veri.isnull().sum()
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# dtype: int64

# %%
veri.drop('state',axis=1,inplace=True)
veri.tail(10)
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2658  2578           Yao Hsiao Tung  82.0      1000.0  2022      4
# 2659  2578              Yao Liangbo  53.0      1000.0  2022      4
# 2660  2578              Ye Qiongjiu  67.0      1000.0  2022      4
# 2661  2578   Richard Yuengling, Jr.  79.0      1000.0  2022      4
# 2662  2578             Zhang Kapeng  57.0      1000.0  2022      4
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                         category                   source        country  \
# 2658               Manufacturing            Manufacturing      Singapore
# 2659            Fashion & Retail      furniture retailing          China
# ...

# %%
veri.drop('month',axis=1,inplace=True)

# %%
veri['personName'].value_counts()
# Out:
# Li Li                      2
# Wang Yanqing & family      2
# Elon Musk                  1
# M.Satyanarayana Reddy      1
# Deepak Mehta               1
#                           ..
# Fu Liquan & family         1
# David Gottesman            1
# Laurence Graff & family    1
# Jeff T. Green              1
# Zhuang Kuilong & family    1
# Name: personName, Length: 2666, dtype: int64

# %%
veri.loc[veri['category']=='Technology'].head(15)
# Out:
#     rank        personName   age  finalWorth  year    category  \
# 1      2        Jeff Bezos  58.0    171000.0  2022  Technology
# 3      4        Bill Gates  66.0    129000.0  2022  Technology
# 5      6        Larry Page  49.0    111000.0  2022  Technology
# 6      7       Sergey Brin  48.0    107000.0  2022  Technology
# 7      8     Larry Ellison  77.0    106000.0  2022  Technology
# 8      9     Steve Ballmer  66.0     91400.0  2022  Technology
# 14    15   Mark Zuckerberg  37.0     67300.0  2022  Technology
# 23    24      Michael Dell  57.0     55100.0  2022  Technology
# 29    30   MacKenzie Scott  51.0     43600.0  2022  Technology
# 33    34        Ma Huateng  50.0     37200.0  2022  Technology
# 46    47        Shiv Nadar  76.0     28700.0  2022  Technology
# 54    55  William Lei Ding  50.0     25200.0  2022  Technology
# 67    67           Jack Ma  57.0     22800.0  2022  Technology
# 69    70      Eric Schmidt  66.0     22100.0  2022  Technology
# ...

# %%
veri.describe()
# Out:
#               rank          age     finalWorth    year
# count  2668.000000  2582.000000    2668.000000  2668.0
# mean   1302.919040    64.210689    4762.350075  2022.0
# std     747.807782    13.401258   10540.482258     0.0
# min       1.000000    19.000000    1000.000000  2022.0
# 25%     665.000000    55.000000    1500.000000  2022.0
# 50%    1292.000000    64.000000    2400.000000  2022.0
# 75%    1929.000000    74.000000    4300.000000  2022.0
# max    2578.000000   100.000000  219000.000000  2022.0

# %%
veri['category'].value_counts().plot.bar(figsize=(10,5))
# Out:
# <Axes: >

# %%
veri.groupby(['country'])['finalWorth'].mean().plot.bar(figsize=(20,10),color='Red')
# Out:
# <Axes: xlabel='country'>

# %%
data=veri.loc[(veri['country']=='United States')]
data.head()
# Out:
#    rank      personName   age  finalWorth  year               category  \
# 0     1       Elon Musk  50.0    219000.0  2022             Automotive
# 1     2      Jeff Bezos  58.0    171000.0  2022             Technology
# 3     4      Bill Gates  66.0    129000.0  2022             Technology
# 4     5  Warren Buffett  91.0    118000.0  2022  Finance & Investments
# 5     6      Larry Page  49.0    111000.0  2022             Technology
#
#                source        country       city countryOfCitizenship  \
# 0       Tesla, SpaceX  United States     Austin        United States
# 1              Amazon  United States    Seattle        United States
# 3           Microsoft  United States     Medina        United States
# 4  Berkshire Hathaway  United States      Omaha        United States
# 5              Google  United States  Palo Alto        United States
#
#                       organization  selfMade gender   birthDate         title
# ...

# %%
result=veri.loc[(veri['country']=='United States') & (veri['category']=='Technology')]
result.head(10)
# Out:
#     rank       personName   age  finalWorth  year    category          source  \
# 1      2       Jeff Bezos  58.0    171000.0  2022  Technology          Amazon
# 3      4       Bill Gates  66.0    129000.0  2022  Technology       Microsoft
# 5      6       Larry Page  49.0    111000.0  2022  Technology          Google
# 6      7      Sergey Brin  48.0    107000.0  2022  Technology          Google
# 7      8    Larry Ellison  77.0    106000.0  2022  Technology        software
# 8      9    Steve Ballmer  66.0     91400.0  2022  Technology       Microsoft
# 14    15  Mark Zuckerberg  37.0     67300.0  2022  Technology        Facebook
# 23    24     Michael Dell  57.0     55100.0  2022  Technology  Dell computers
# 29    30  MacKenzie Scott  51.0     43600.0  2022  Technology          Amazon
# 69    70     Eric Schmidt  66.0     22100.0  2022  Technology          Google
#
#           country         city countryOfCitizenship  \
# 1   United States      Seattle        United States
# ...

# %%
veri['gender'].value_counts()
# Out:
# M    2341
# F     311
# Name: gender, dtype: int64
